# %% [markdown]
# # Create example dataset
# This notebook is intended to create an example dataset for the purpose of testing the functionality of the [training notebook](./train_unsloth_to_hub.ipynb)

# %%
#@title Instantiate messages (click to expand)

from model_tuning_workspace.prompting.system_msg import sys_msg

usr_msg = """# Docs

## autopsy
State Name
State Medical Examiner’s Office
123 Sesame Street

Voice (123)334-2200 – Fax (012)345-6789

Autopsy report

Name: Jane Doe SME case #52-00000
Date of examination: January 32, 2052

Final Pathological Diagnosis

I. Gunshot wound of head.
a. Entrance: anterior scalp/forehead.
b. Exit: posterosuperior scalp just right of posterior midline.
c. Pathway: skin and subcutaneous soft tissue of anterior scalp/forehead, calvarial skull, brain,
posterior calvarium and posterosuperior scalp.
d. Associated injuries: perforation of skin and subcutaneous soft tissue of forehead, scalp, face
and posterior scalp. There is extensive fracturing of the calvarial and basilar skull.
Pulpefaction and hemorrhage of brain tissue along the wound pathway. Extensive laceration
and subarachnoid hemorrhage of brain with partial extrusion of brain from posterior exit
wound.
e. Trajectory: front to back.
f. Clinical history of lumbar pain
g. Projectile: no projectile is recovered.
h. Postmortem blood alcohol content of .250

PRIVILEGED DOCUMENT DO NOT DUPLICATE NOR DISTRIBUTE PER AS19.63.020(a)

52-00000
Page 5
Opinion

The cause of death of this 30-year-old female is self-inflicted gunshot wound of head. From the scene
investigation, autopsy examination and circumstances surrounding the death, as currently known, the
manner of death is classified as suicide.

_______________
Juan Doe, MD
Medical Examiner

____________________
Date signed

PRIVILEGED DOCUMENT DO NOT DUPLICATE NOR DISTRIBUTE PER AS19.63.020(a)

52-00000
Page 5
External EXAMINATION

Identification
The body is identified at the time of examination by a Medical Examiner tag bearing the decedent’s name
“Jane Doe” and case number 52-00000. Identification was confirmed through fingerprints
CLOTHING AND PERSONAL EFFECTS
The following articles of clothing and personal effects are on or accompany the body at the time of
examination:
1. T-shirt.
2. Down jacket.
3. socks x 2.
4. black pants.
5. Underwear.
6. One pair of high heels.
7. Two empty paper handbags over hands secured by elastic bands
GENERAL DESCRIPTION
The body is that of a well-developed, female appearing consistent with the reported age of 30 years. The
body weighs 180 pounds and measures 65 inches in height. The body is cool to the touch and has been
previously refrigerated. Rigor mortis is 4+ in the extremities. The body is showing faint gray color change
of early decomposition change over a 6 x 8 cm distribution in the left lower quadrant of the chest. The body
has not been embalmed.
The scalp is covered with blonde hair, measuring 13 inches in length. The eyes are natural with blue irides
and white sclerae. The ears are normally formed and symmetric. The nose appears normally formed. The
mouth is atraumatic. The oral cavity contains natural teeth in good condition. The upper and lower frenula
are intact. Two white gauze like paper fragments are between the upper lip and upper jaw. These fragments
measure 2.8 x 2.5 cm in aggregate (two separate pieces). The neck is normally formed. The chest and breasts
are well formed and symmetric. The abdomen is flat.
The upper extremities are normally formed as are the hands. The shoulder to fingertip length of the right
arm is 28 inches. The fingernails are trimmed 1/8 inch beyond the nail beds. The lower extremities are
normally formed as are the feet. The toenails are trimmed 1/16 inch beyond the nail beds. The soles of the
feet are unremarkable. The external genitalia are those of a normally developed adult. The back and anus
are normally formed.
SCARS AND DISTINGUISHING MARKS
1. A tattoo of the name “AARON” on the right lower leg.
2. A tattoo of the outline of the state of West Virginia on the upper left scapula.

PRIVILEGED DOCUMENT DO NOT DUPLICATE NOR DISTRIBUTE PER AS19.63.020(a)

52-00000
Page 5

EVIDENCE OF MEDICAL THERAPY

Endotracheal tube placed in throat.

EVIDENCE OF INJURIES

DOE, JANE
0000-00000
AB0000
1/1/1993
Female
00000

None Detected

See Detailed Findings section for additional information
Testing Requested:
Test Test Name
8051TI
Specimens
Received:

Postmortem, Basic, Tissue (Forensic)

ID Tube/ContainerVolume/ Collection Matrix Source Mass Date/Time Labeled As
001 Red Stopper Glass
Tube

0.2 mL 11/21/2023 Vitreous Fluid 2023-02555

002 Red Stopper Glass
Tube

9 mL 11/21/2023 Urine 2023-02555
003 Plastic Bag 77.9 g 11/21/2023 Liver Tissue 23-2555
004 Homogenate
Container

Not Given 11/21/2023 Liver Tissue Not Applicable

All sample volumes/weights are approximations. Specimens received on
02/05/2024.

v.27.0

CONFIDENTIAL Workorder 00000
Chain AB0000
Patient ID 0000-0000
Page 2 of 2

Detailed Findings:
Examination of the specimen(s) submitted did not reveal any positive findings of toxicological significance by
procedures outlined in the accompanying Analysis Summary.
Sample Comments:
001 Physician/Pathologist Name: Juan Doe
003 Tissue specimen required homogenization: 0000-003
004 Labs generated homogenized Tissue sample: 0000-004
Unless alternate arrangements are made by you, the remainder of the submitted specimens will be discarded two (2)
years from the date of this report; and generated data will be discarded five (5) years from the date the analyses were
performed.

Workorder 0000 was electronically signed on
1/32/2024 18:02 by:
John Smith, Ph.D., F-ABFT
Forensic Toxicologist

Analysis Summary and Reporting Limits:
All of the following tests were performed for this case. For each test, the compounds listed were included in the scope. The
Reporting Limit listed for each compound represents the lowest concentration of the compound that will be reported as being
positive. If the compound is listed as None Detected, it is not present above the Reporting Limit. Please refer to the Positive
Findings section of the report for those compounds that were identified as being present.
Test 8051TI - Postmortem, Basic, Tissue (Forensic) - Liver Tissue
-Analysis by Enzyme-Linked Immunosorbent Assay (ELISA) for:
Analyte Rpt. Limit Analyte Rpt. Limit
Amphetamines 80 ng/g
Barbiturates 0.16 mcg/g
Benzodiazepines 400 ng/g Buprenorphine /
Metabolite 2.0 ng/g Cannabinoids 40 ng/g
Cocaine / Metabolites 80 ng/g
-Analysis by Headspace Gas Chromatography (GC) for:

Fentanyl / Acetyl Fentanyl
Methadone / Metabolite
Methamphetamine / MDMA
Opiates
Oxycodone / Oxymorphone
Phencyclidine

4.0 ng/g
100 ng/g
80 ng/g
80 ng/g
40 ng/g
40 ng/g

Analyte Rpt. Limit Analyte Rpt. Limit
Acetone 20 mg/100 g
Ethanol 80 mg/100 g

Isopropanol
Methanol

20 mg/100 g
40 mg/100 g
Digital data review may have taken place remotely by qualified staff utilizing a secure VPN connection for some or all of the reported results. This is in accordance with and
follows CLIA regulations."""

ai_msg = """In the morning hours, a 30-year-old female victim was found deceased on her sofa in the living room of her residence. Prior to the incident, V had contacted her brother stating her intention to commit suicide. The brother alerted police who gained access to the residence through the landlord. V, who had a medical history of PTSD, anxiety, and chronic lumbar pain, was discovered with a devastating self-inflicted gunshot wound to the head from a shotgun found on her lap. V and her spouse were separated at the time of the incident. The autopsy revealed a gunshot entrance wound on the anterior forehead with an exit wound on the posterior scalp, causing extensive fracturing of the skull and brain trauma. Toxicology showed a postmortem blood alcohol content of .250."""

# %% [markdown]
# ## Prep the conversation

# %%
conversation = [
    {"role": "system", "content": sys_msg},
    {"role": "user", "content": usr_msg},
    {"role": "assistant", "content": ai_msg}
]

conversation_map = {"conversation": conversation}

# %% [markdown]
# ## Export to jsonl

# %%
import json

with open("example_dataset.jsonl", 'w', encoding='utf-8') as f:
    f.write(json.dumps(conversation_map) + "\n")
